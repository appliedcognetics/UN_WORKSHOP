# %%
# %pip install reportlab
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: C:\Users\ccoulthrust\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ##  Card Design
#
# Generate a list of cards we would want to create.
#
# - User Profile Cards
# - Agent Cards
# - Knowledge Cards
#  - Course Catalog Cards
#  - Learning Framework Cards
#  - Organization Goals Cards
#
#
# ## Review "Agentic AI Game Design" in ChatGPT
#
# ## User Profile Cards Prompt Example
# ```text
# I need 8 user profile cards in json format that I can use to create user profile cards
#
#         User Profile Cards
#         Example Attributes:
#         CardType : User Profile
#         Name : Make up a name
#         Country of Domicile: “United States”
#         Age: “30”
#         Education Level: “Bachelor’s Degree”
#         Occupation: Come up with an occupation, e.g., Farmer, Teacher, Software Engineer, Student
#         Language Skills: “English, Spanish”
#         Interests: Come up with with 2 interests , these can be hobbies, professional interests, etc.
#         Learning Preferences: “Visual, Hands-on”
#         Goal: AI Related Skill Development come up with a sentence with 2 attibutes
#         Skill Level: [Beginner, Intermediate, Advanced]
#         Constraint:  Come up with at most 2 constraints for each card
#
#
#  These cards drive each “scenario round.”
# ```
#
# ## Agent Cards
#
# ````text
# I need 8 agent cards in json format that I can use to create agent cards
#
#   1. Agent Cards (Max 6 Types)
#
#   I need 8 agent cards in json format that I can use to create agent cards.
# Each agent has:
#
# - A role (what it's good at)
# - Abilities (e.g., "query", "evaluate", "route")
# - Built-in strengths/weaknesses (e.g., high reasoning but no memory)
# - Input/Output expectations
#
#
# | Agent Type | Description |
# |------------|-------------|
# | Web Search Agent | Finds current data or context from the web |
# | Skills Evaluator Agent | Assesses user abilities based on goals/data |
# | Plan Builder Agent | Creates a learning or action plan |
# | Summarizer Agent | Reduces long input into key points |
# | Memory Agent | Stores/retrieves relevant facts or prior turns |
# | Orchestrator Agent | Routes input/output and triggers next agents |
#
# Use this format
#     {
#         "CardType": "Agent Card",
#         "Title": Agent Type here ,
#         "Description": "Intro to AI concepts like machine learning and responsible AI for beginners.",
#         "Role"
#         "Summary of Instructions": A brief description of the agent instructions and capabilities,
#         "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
#         "Abilities":
#         "Strengths": ["High reasoning", "No memory"],
#         "Input-Output": "Beginner",
#         "bgcolor": "#D5F4E6",
#         "image": "./images/bot.png"
#     },
# ```
# ## Knowledge Cards
#
# ```text
# I want some content cards for the knowledge store as well, these will be content about the subject lets say 4 content cards.  the domain is eductional development so I would need content about educational programs
#
# ```
#
# ```text
# ok I like those content cards, now lets  get some sample content cards for on the subject of  AI learning, if a user wants to learn about AI  give me 4 cards for that subject in the same format
# ```

# %% [markdown]
# new version

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor
from reportlab.lib.utils import ImageReader

# AI Learning Content Cards JSON data with shared image
cards = [
    {
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "Intro to AI concepts like machine learning and responsible AI for beginners.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#D5F4E6",
        "image": "./images/bot.png"
    },
    {
        "Title": "How Large Language Models Work",
        "Description": "Explains the core architecture of LLMs like GPT, BERT, and T5.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FCEBB6",
        "image": "./images/bot.png"
    },
    {
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Learn to build an AI chatbot using no-code user and pretrained models.",
        "Tags": ["AI user", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFCCCB",
        "image": "./images/bot.png"
    },
    {
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "Explore frameworks and techniques for building ethical and transparent AI.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#BFD8B8",
        "image": "./images/bot.png"
    }
]

# PDF Settings
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2

# Create the PDF canvas
c = canvas.Canvas("ai_learning_cards.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)

    # Background color
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Title
    c.setFillColor(HexColor("#000000"))
    c.setFont("Helvetica-Bold", 14)
    c.drawCentredString(x + card_width / 2, y + card_height - 0.5 * inch, card["Title"])

    # Description
    c.setFont("Helvetica", 10)
    c.drawCentredString(x + card_width / 2, y + card_height - 1.0 * inch, card["Description"])

    # Format and Difficulty
    c.setFont("Helvetica", 9)
    c.drawCentredString(x + card_width / 2, y + 0.7 * inch, f"Format: {card['Format']}")
    c.drawCentredString(x + card_width / 2, y + 0.5 * inch, f"Difficulty: {card['Difficulty']}")

    # Tags
    tags_str = "Tags: " + ", ".join(card["Tags"])
    c.drawCentredString(x + card_width / 2, y + 0.3 * inch, tags_str)

    # Shared image
    try:
        img = ImageReader(card["image"])
        img_size = 1.0 * inch
        c.drawImage(
            img,
            x + (card_width - img_size) / 2,
            y + (card_height / 2) - (img_size / 2),
            width=img_size,
            height=img_size,
            preserveAspectRatio=True,
            mask='auto'
        )
    except:
        pass

    # New page every 4 cards
    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# v2

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor
from reportlab.lib.utils import ImageReader
import textwrap

# PDF & card layout settings
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2

# Updated card list (sample included here)
cards = [
    {
        "CardType": "Knowledge Card",
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "Intro to AI concepts like machine learning and responsible AI for beginners.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#D5F4E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "How Large Language Models Work",
        "Description": "Explains the core architecture of LLMs like GPT, BERT, and T5.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FCEBB6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Learn to build an AI chatbot using no-code user and pretrained models.",
        "Tags": ["AI user", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFCCCB",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "Explore frameworks and techniques for building ethical and transparent AI.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#BFD8B8",
        "image": "./images/bot.png"
    }
]

# Create the PDF canvas
c = canvas.Canvas("ai_learning_cardsv2.pdf", pagesize=letter)

def draw_wrapped_text(c, text, x_center, y_start, max_width, font_name, font_size, leading):
    c.setFont(font_name, font_size)
    lines = textwrap.wrap(text, width=int(max_width / (font_size * 0.6)))
    for i, line in enumerate(lines):
        c.drawCentredString(x_center, y_start - i * leading, line)
    return y_start - len(lines) * leading

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2

    # Background color
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Card Type
    c.setFillColor(HexColor("#000000"))
    c.setFont("Helvetica-Bold", 10)
    c.drawCentredString(center_x, y + card_height - 0.3 * inch, card["CardType"])

    # Title (wrapped)
    y_pos = draw_wrapped_text(
        c, card["Title"], center_x, y + card_height - 0.6 * inch,
        card_width - 0.4 * inch, "Helvetica-Bold", 12, 14
    )

    # Image (smaller)
    try:
        img = ImageReader(card["image"])
        img_size = 0.8 * inch
        c.drawImage(
            img,
            center_x - img_size / 2,
            y_pos - img_size - 0.1 * inch,
            width=img_size,
            height=img_size,
            preserveAspectRatio=True,
            mask='auto'
        )
        y_pos = y_pos - img_size - 0.2 * inch
    except:
        y_pos = y_pos - 0.4 * inch

    # Description
    y_pos = draw_wrapped_text(
        c, card["Description"], center_x, y_pos,
        card_width - 0.4 * inch, "Helvetica", 10, 12
    )

    # Format & Difficulty
    c.setFont("Helvetica-Bold", 9)
    c.drawCentredString(center_x, y + 0.9 * inch, f"Format: {card['Format']}")
    c.drawCentredString(center_x, y + 0.7 * inch, f"Difficulty: {card['Difficulty']}")

    # Tags
    tags_str = "Tags: " + ", ".join(card["Tags"])
    draw_wrapped_text(c, tags_str, center_x, y + 0.5 * inch, card_width - 0.4 * inch, "Helvetica", 8, 10)

    # Page break every 4 cards
    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# refactored after giving it the pdf

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black, white
from reportlab.lib.utils import ImageReader
import textwrap

# Page and card layout
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2
margin = 0.2 * inch

cards = [
    {
        "CardType": "Knowledge Card",
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "Intro to AI concepts like machine learning and responsible AI for beginners.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#D5F4E6",
        "image": ""
    },
    {
        "CardType": "Knowledge Card",
        "Title": "How Large Language Models Work",
        "Description": "Explains the core architecture of LLMs like GPT, BERT, and T5.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FCEBB6",
        "image": ""
    },
    {
        "CardType": "Knowledge Card",
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Learn to build an AI chatbot using no-code user and pretrained models.",
        "Tags": ["AI user", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFCCCB",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "Explore frameworks and techniques for building ethical and transparent AI.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#BFD8B8",
        "image": "./images/bot.png"
    }
]

def draw_wrapped_text(c, text, x_center, y_start, width, font_name, font_size, leading):
    c.setFont(font_name, font_size)
    lines = textwrap.wrap(text, width=int(width / (font_size * 0.55)))
    for i, line in enumerate(lines):
        c.drawCentredString(x_center, y_start - i * leading, line)
    return y_start - len(lines) * leading

c = canvas.Canvas("ai_learning_cards_styled.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2

    # Card background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.roundRect(x + margin, y + margin, card_width - 2 * margin, card_height - 2 * margin, 10, fill=True, stroke=False)

    # Card type tag
    c.setFont("Helvetica-Bold", 8)
    c.setFillColor(HexColor("#444444"))
    c.drawCentredString(center_x, y + card_height - 0.35 * inch, card["CardType"])

    # Title box
    c.setFillColor(white)
    c.roundRect(x + margin + 0.1 * inch, y + card_height - 0.75 * inch, card_width - 2 * margin - 0.2 * inch, 0.4 * inch, 5, fill=True, stroke=False)
    c.setFillColor(black)
    draw_wrapped_text(c, card["Title"], center_x, y + card_height - 0.6 * inch, card_width - 0.4 * inch, "Helvetica-Bold", 11, 13)

    # Image
    try:
        img = ImageReader(card["image"])
        img_size = 0.7 * inch
        c.drawImage(
            img,
            center_x - img_size / 2,
            y + card_height - 1.5 * inch,
            width=img_size,
            height=img_size,
            preserveAspectRatio=True,
            mask='auto'
        )
    except:
        pass

    # Description
    y_pos = draw_wrapped_text(c, card["Description"], center_x, y + card_height - 2.0 * inch, card_width - 0.4 * inch, "Helvetica", 9, 11)

    # Format & Difficulty
    c.setFont("Helvetica-Bold", 9)
    c.drawCentredString(center_x, y + 1.1 * inch, f"Format: {card['Format']}")
    c.drawCentredString(center_x, y + 0.95 * inch, f"Difficulty: {card['Difficulty']}")

    # Tags
    tags_str = "Tags: " + ", ".join(card["Tags"])
    draw_wrapped_text(c, tags_str, center_x, y + 0.75 * inch, card_width - 0.4 * inch, "Helvetica-Oblique", 8, 10)

    # Page break
    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# v3

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.lib.utils import ImageReader
import textwrap

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2
margin = 0.2 * inch

# Sample cards
cards = [
    {
        "CardType": "Knowledge Card",
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "Intro to AI concepts like machine learning and responsible AI for beginners.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#D5F4E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "How Large Language Models Work",
        "Description": "Explains the core architecture of LLMs like GPT, BERT, and T5.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FCEBB6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Learn to build an AI chatbot using no-code user and pretrained models.",
        "Tags": ["AI user", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFCCCB",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "Explore frameworks and techniques for building ethical and transparent AI.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#BFD8B8",
        "image": "./images/bot.png"
    }
]

# Utility to wrap and draw centered text
def draw_wrapped_text(c, text, x_center, y_start, width, font_name, font_size, leading, bold_labels=False):
    c.setFont(font_name, font_size)
    lines = textwrap.wrap(text, width=int(width / (font_size * 0.55)))
    for i, line in enumerate(lines):
        if bold_labels and ':' in line:
            parts = line.split(':', 1)
            label = parts[0] + ":"
            value = parts[1].strip()
            label_width = c.stringWidth(label, font_name + "-Bold", font_size)
            value_width = c.stringWidth(value, font_name, font_size)
            total_width = label_width + value_width + 4
            x_start = x_center - total_width / 2
            c.setFont(font_name + "-Bold", font_size)
            c.drawString(x_start, y_start - i * leading, label)
            c.setFont(font_name, font_size)
            c.drawString(x_start + label_width + 4, y_start - i * leading, value)
        else:
            c.drawCentredString(x_center, y_start - i * leading, line)
    return y_start - len(lines) * leading

# Create canvas
c = canvas.Canvas("ai_learning_cards_finalv3.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2

    # Card background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.roundRect(x + margin, y + margin, card_width - 2 * margin, card_height - 2 * margin, 10, fill=True, stroke=False)

    # Card type (top)
    c.setFont("Helvetica-Bold", 8)
    c.setFillColor(black)
    c.drawCentredString(center_x, y + card_height - 0.35 * inch, card["CardType"])

    # Title (large & bold)
    c.setFont("Helvetica-Bold", 14)
    title_lines = textwrap.wrap(card["Title"], width=30)
    for j, line in enumerate(title_lines):
        c.drawCentredString(center_x, y + card_height - (0.6 + j * 0.25) * inch, line)

    # Image (smaller, centered)
    img_y = y + card_height - (0.6 + len(title_lines) * 0.25 + 0.1) * inch - 0.7 * inch
    try:
        img = ImageReader(card["image"])
        img_size = 0.6 * inch
        c.drawImage(
            img,
            center_x - img_size / 2,
            img_y,
            width=img_size,
            height=img_size,
            preserveAspectRatio=True,
            mask='auto'
        )
    except:
        pass

    # Description
    desc_y = img_y - 0.2 * inch
    desc_y = draw_wrapped_text(
        c, card["Description"], center_x, desc_y,
        card_width - 0.4 * inch, "Helvetica", 10, 12
    )

    # Format and Difficulty
    meta_lines = [
        f"Format: {card['Format']}",
        f"Difficulty: {card['Difficulty']}"
    ]
    meta_y = desc_y - 0.2 * inch
    for line in meta_lines:
        meta_y = draw_wrapped_text(
            c, line, center_x, meta_y,
            card_width - 0.4 * inch, "Helvetica", 10, 12, bold_labels=True
        )

    # Tags
    tags_str = "Tags: " + ", ".join(card["Tags"])
    draw_wrapped_text(
        c, tags_str, center_x, meta_y - 0.2 * inch,
        card_width - 0.4 * inch, "Helvetica", 10, 12, bold_labels=True
    )

    # Page break
    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# v4

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.lib.utils import ImageReader
import textwrap

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2
margin = 0.2 * inch

cards = [
    {
        "CardType": "Knowledge Card",
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "Intro to AI concepts like machine learning and responsible AI for beginners.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#D5F4E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "How Large Language Models Work",
        "Description": "Explains the core architecture of LLMs like GPT, BERT, and T5.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FCEBB6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Learn to build an AI chatbot using no-code tools and pretrained models.",
        "Tags": ["AI Tools", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFCCCB",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "Explore frameworks and techniques for building ethical and transparent AI.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#BFD8B8",
        "image": "./images/bot.png"
    }
]

# Utility to wrap and draw left-aligned text
def draw_wrapped_left_text(c, text, x_left, y_start, width, font_name, font_size, leading):
    c.setFont(font_name, font_size)
    lines = textwrap.wrap(text, width=int(width / (font_size * 0.55)))
    for i, line in enumerate(lines):
        c.drawString(x_left, y_start - i * leading, line)
    return y_start - len(lines) * leading

# Create canvas
c = canvas.Canvas("ai_learning_cards_final_v5.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2
    left_x = x + margin + 0.15 * inch

    # Card background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.roundRect(x + margin, y + margin, card_width - 2 * margin, card_height - 2 * margin, 10, fill=True, stroke=False)

    # Card Type (large & centered)
    c.setFont("Helvetica-Bold", 12)
    c.setFillColor(black)
    c.drawCentredString(center_x, y + card_height - 0.35 * inch, card["CardType"])

    # Title (slightly smaller)
    c.setFont("Helvetica-Bold", 11)
    title_lines = textwrap.wrap(card["Title"], width=34)
    for j, line in enumerate(title_lines):
        c.drawCentredString(center_x, y + card_height - (0.6 + j * 0.22) * inch, line)

    # Image
    img_y = y + card_height - (0.6 + len(title_lines) * 0.22 + 0.1) * inch - 0.65 * inch
    try:
        img = ImageReader(card["image"])
        img_size = 0.6 * inch
        c.drawImage(
            img,
            center_x - img_size / 2,
            img_y,
            width=img_size,
            height=img_size,
            preserveAspectRatio=True,
            mask='auto'
        )
    except:
        pass

    # Info Block
    info_y = img_y - 0.25 * inch
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, info_y, "Description:")
    c.setFont("Helvetica", 10)
    info_y = draw_wrapped_left_text(c, card["Description"], left_x, info_y - 14, card_width - 0.4 * inch, "Helvetica", 10, 12)

    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, info_y - 10, "Format:")
    c.setFont("Helvetica", 10)
    info_y = draw_wrapped_left_text(c, card["Format"], left_x, info_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, info_y - 10, "Difficulty:")
    c.setFont("Helvetica", 10)
    info_y = draw_wrapped_left_text(c, card["Difficulty"], left_x, info_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, info_y - 10, "Tags:")
    c.setFont("Helvetica", 10)
    tags_text = ", ".join(card["Tags"])
    draw_wrapped_left_text(c, tags_text, left_x, info_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# v6

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.lib.utils import ImageReader
import textwrap

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2
margin = 0.2 * inch

# Updated card data with extended descriptions and content type
cards = [
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "This content explores essential frameworks and actionable strategies for building transparent, fair, and accountable AI systems. It covers real-world case studies, introduces ethical considerations in machine learning, and provides guidance on mitigating bias and increasing explainability in model outcomes.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#BFD8B8",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "A foundational overview of artificial intelligence for those without a technical background. This card covers key ideas such as machine learning, automation, and responsible AI, helping learners build awareness and confidence in AI-related discussions and decisions.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#D5F4E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "How Large Language Models Work",
        "Description": "Delve into the architecture and function of large language models like GPT, BERT, and T5. Learners will explore how these models generate text, understand prompts, and how they can be applied in enterprise and everyday tools.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FCEBB6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Walk through the development of an AI-driven application using no-code platforms. Ideal for non-programmers, this card guides learners through using tools like Power Platform or Bubble to deploy useful, AI-powered solutions.",
        "Tags": ["AI Tools", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFCCCB",
        "image": "./images/bot.png"
    }
]

# Utility function for left-aligned wrapped text
def draw_wrapped_left_text(c, text, x_left, y_start, width, font_name, font_size, leading):
    c.setFont(font_name, font_size)
    lines = textwrap.wrap(text, width=int(width / (font_size * 0.55)))
    for i, line in enumerate(lines):
        c.drawString(x_left, y_start - i * leading, line)
    return y_start - len(lines) * leading

# Create PDF canvas
c = canvas.Canvas("ai_learning_cards_final_outputv7.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2
    left_x = x + margin + 0.15 * inch

    # Background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.roundRect(x + margin, y + margin, card_width - 2 * margin, card_height - 2 * margin, 10, fill=True, stroke=False)

    # Card Type
    c.setFillColor(black)
    c.setFont("Helvetica-Bold", 12)
    c.drawCentredString(center_x, y + card_height - 0.35 * inch, card["CardType"])

    # Content Type
    c.setFont("Helvetica", 10)
    c.drawCentredString(center_x, y + card_height - 0.55 * inch, card["ContentType"])

    # Title (medium size, centered)
    c.setFont("Helvetica-Bold", 11)
    title_lines = textwrap.wrap(card["Title"], width=34)
    for j, line in enumerate(title_lines):
        c.drawCentredString(center_x, y + card_height - (0.8 + j * 0.22) * inch, line)

    # Image (optional)
    img_y = y + card_height - (0.8 + len(title_lines) * 0.22 + 0.1) * inch - 0.6 * inch
    try:
        img = ImageReader(card["image"])
        img_size = 0.6 * inch
        c.drawImage(
            img,
            center_x - img_size / 2,
            img_y,
            width=img_size,
            height=img_size,
            preserveAspectRatio=True,
            mask='auto'
        )
    except:
        pass

    # Description
    desc_y = img_y - 0.25 * inch
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, desc_y, "Description:")
    c.setFont("Helvetica", 10)
    desc_y = draw_wrapped_left_text(c, card["Description"], left_x, desc_y - 14, card_width - 0.4 * inch, "Helvetica", 10, 12)

    # Format
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, desc_y - 10, "Format:")
    c.setFont("Helvetica", 10)
    desc_y = draw_wrapped_left_text(c, card["Format"], left_x, desc_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    # Difficulty
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, desc_y - 10, "Difficulty:")
    c.setFont("Helvetica", 10)
    desc_y = draw_wrapped_left_text(c, card["Difficulty"], left_x, desc_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    # Tags
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, desc_y - 10, "Tags:")
    c.setFont("Helvetica", 10)
    tags_text = ", ".join(card["Tags"])
    draw_wrapped_left_text(c, tags_text, left_x, desc_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# v8

# %% [markdown]
# | Color Name      | Hex Code  | Notes                    |
# | --------------- | --------- | ------------------------ |
# | Very Light Gray | `#F9F9F9` | Super minimal ink        |
# | Pale Blue       | `#EAF4FF` | Cool tone, good contrast |
# | Pale Yellow     | `#FFFDE7` | Friendly, low-ink yellow |
# | Light Mint      | `#E7FFF3` | Calming, very readable   |
# | Soft Peach      | `#FFF1E6` | Warm but subtle          |
# | Pale Lavender   | `#F3E9FF` | Light and gentle on eyes |

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.lib.utils import ImageReader
import textwrap

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2

# Card data
cards = [
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "This content explores essential frameworks and actionable strategies for building transparent, fair, and accountable AI systems. It covers real-world case studies, introduces ethical considerations in machine learning, and provides guidance on mitigating bias and increasing explainability in model outcomes.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#EAF4FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "A foundational overview of artificial intelligence for those without a technical background. This card covers key ideas such as machine learning, automation, and responsible AI, helping learners build awareness and confidence in AI-related discussions and decisions.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#E7FFF3",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "How Large Language Models Work",
        "Description": "Delve into the architecture and function of large language models like GPT, BERT, and T5. Learners will explore how these models generate text, understand prompts, and how they can be applied in enterprise and everyday tools.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFF1E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Walk through the development of an AI-driven application using no-code platforms. Ideal for non-programmers, this card guides learners through using tools like Power Platform or Bubble to deploy useful, AI-powered solutions.",
        "Tags": ["AI Tools", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#F3E9FF",
        "image": "./images/bot.png"
    }
]

# Utility: left-aligned wrapped text
def draw_wrapped_left_text(c, text, x_left, y_start, width, font_name, font_size, leading):
    c.setFont(font_name, font_size)
    lines = textwrap.wrap(text, width=int(width / (font_size * 0.55)))
    for i, line in enumerate(lines):
        c.drawString(x_left, y_start - i * leading, line)
    return y_start - len(lines) * leading

# Create canvas
c = canvas.Canvas("ai_learning_cards_no_margins.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2
    left_x = x + 0.3 * inch

    # Background (full card area, no margins)
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Card Type - centered top
    c.setFillColor(black)
    c.setFont("Helvetica-Bold", 12)
    c.drawCentredString(center_x, y + card_height - 0.35 * inch, card["CardType"])

    # Content Type
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, y + card_height - 0.65 * inch, "Content Type:")
    c.setFont("Helvetica", 10)
    c.drawString(left_x + 1.2 * inch, y + card_height - 0.65 * inch, card["ContentType"])

    # Title
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, y + card_height - 0.85 * inch, "Title:")
    c.setFont("Helvetica", 10)
    title_y = draw_wrapped_left_text(c, card["Title"], left_x + 0.6 * inch, y + card_height - 0.85 * inch, card_width - 0.8 * inch, "Helvetica", 10, 12)

    # Image (optional)
    img_y = title_y - 0.25 * inch
    try:
        img = ImageReader(card["image"])
        img_size = 0.6 * inch
        c.drawImage(
            img,
            center_x - img_size / 2,
            img_y,
            width=img_size,
            height=img_size,
            preserveAspectRatio=True,
            mask='auto'
        )
    except:
        pass

    # Description
    desc_y = img_y - 0.25 * inch
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, desc_y, "Description:")
    c.setFont("Helvetica", 10)
    desc_y = draw_wrapped_left_text(c, card["Description"], left_x, desc_y - 14, card_width - 0.4 * inch, "Helvetica", 10, 12)

    # Format
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, desc_y - 10, "Format:")
    c.setFont("Helvetica", 10)
    desc_y = draw_wrapped_left_text(c, card["Format"], left_x + 0.6 * inch, desc_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    # Difficulty
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, desc_y - 10, "Difficulty:")
    c.setFont("Helvetica", 10)
    desc_y = draw_wrapped_left_text(c, card["Difficulty"], left_x + 0.8 * inch, desc_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    # Tags
    c.setFont("Helvetica-Bold", 10)
    c.drawString(left_x, desc_y - 10, "Tags:")
    c.setFont("Helvetica", 10)
    tags_text = ", ".join(card["Tags"])
    draw_wrapped_left_text(c, tags_text, left_x + 0.5 * inch, desc_y - 24, card_width - 0.4 * inch, "Helvetica", 10, 12)

    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# v9

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.lib.utils import ImageReader
import textwrap

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2



# Utility: left-aligned wrapped text
def draw_wrapped_left_text(c, label, text, x_left, y_start, width, label_font, text_font, label_size, text_size, leading):
    c.setFont(label_font, label_size)
    c.drawString(x_left, y_start, f"{label}")
    y_start -= leading
    c.setFont(text_font, text_size)
    lines = textwrap.wrap(text, width=int(width / (text_size * 0.55)))
    for i, line in enumerate(lines):
        c.drawString(x_left, y_start - i * leading, line)
    return y_start - len(lines) * leading - 6

# PDF generation
c = canvas.Canvas("ai_learning_cards_refined.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2
    left_x = x + 0.4 * inch
    right_x = x + card_width - 1.0 * inch
    current_y = y + card_height - 0.4 * inch

    # Background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Card Type (centered, bold)
    c.setFillColor(black)
    c.setFont("Helvetica-Bold", 13)
    c.drawCentredString(center_x, current_y, card["CardType"])

    # Image (top-right)
    # try:
    #     img = ImageReader(card["image"])
    #     c.drawImage(img, right_x, current_y - 0.6 * inch, width=0.5 * inch, height=0.5 * inch, preserveAspectRatio=True, mask='auto')
    # except:
    #     pass

    # Content Type
    current_y -= 0.9 * inch
    current_y = draw_wrapped_left_text(
        c, "Content Type:", card["ContentType"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Title
    current_y = draw_wrapped_left_text(
        c, "Title:", card["Title"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Description
    current_y = draw_wrapped_left_text(
        c, "Description:", card["Description"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Format
    current_y = draw_wrapped_left_text(
        c, "Format:", card["Format"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Difficulty
    current_y = draw_wrapped_left_text(
        c, "Difficulty:", card["Difficulty"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Tags
    tag_text = ", ".join(card["Tags"])
    current_y = draw_wrapped_left_text(
        c, "Tags:", tag_text, left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# # v9 - Good Version with Good Colors

# %%
# Sample card data
cards = [
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "This content explores essential frameworks and actionable strategies for building transparent, fair, and accountable AI systems. It covers real-world case studies, introduces ethical considerations in machine learning, and provides guidance on mitigating bias and increasing explainability in model outcomes.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#EAF4FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "A foundational overview of artificial intelligence for those without a technical background. This card covers key ideas such as machine learning, automation, and responsible AI, helping learners build awareness and confidence in AI-related discussions and decisions.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#E7FFF3",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "How Large Language Models Work",
        "Description": "Delve into the architecture and function of large language models like GPT, BERT, and T5. Learners will explore how these models generate text, understand prompts, and how they can be applied in enterprise and everyday tools.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFF1E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Walk through the development of an AI-driven application using no-code platforms. Ideal for non-programmers, this card guides learners through using tools like Power Platform or Bubble to deploy useful, AI-powered solutions.",
        "Tags": ["AI Tools", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#F3E9FF",
        "image": "./images/bot.png"
    }
]

# %% [markdown]
# NEW Return HEre
#
#
# | Color Name      | Hex Code  | Notes                    |
# | --------------- | --------- | ------------------------ |
# | Very Light Gray | `#F9F9F9` | Super minimal ink        |
# | Pale Blue       | `#EAF4FF` | Cool tone, good contrast |
# | Pale Yellow     | `#FFFDE7` | Friendly, low-ink yellow |
# | Light Mint      | `#E7FFF3` | Calming, very readable   |
# | Soft Peach      | `#FFF1E6` | Warm but subtle          |
# | Pale Lavender   | `#F3E9FF` | Light and gentle on eyes |

# %%
cards = [
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Healthcare: Diagnostic Tools",
        "Description": "Learn how AI is revolutionizing healthcare by developing diagnostic tools that assist doctors in identifying diseases. This course covers the basics of AI in medical imaging and predictive diagnostics.",
        "Tags": ["AI", "Healthcare", "Diagnostics"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Advanced",
        "bgcolor": "#EAF4FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Finance: Risk Management",
        "Description": "Understand how AI can be used to manage financial risks. This course explores AI techniques for detecting and mitigating risks in financial markets, including fraud detection and credit scoring.",
        "Tags": ["AI", "Finance", "Risk Management"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFFDE7",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Agriculture: Crop Monitoring",
        "Description": "Discover how AI is used in agriculture to monitor crop health and optimize yields. This course covers AI applications in precision farming, including the use of drones and sensors.",
        "Tags": ["AI", "Agriculture", "Crop Monitoring"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Beginner",
        "bgcolor": "#E7FFF3",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Retail: Customer Insights",
        "Description": "Explore how AI can provide valuable insights into customer behavior in the retail sector. This course covers AI techniques for analyzing customer data and improving marketing strategies.",
        "Tags": ["AI", "Retail", "Customer Insights"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFF1E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Education: Adaptive Learning",
        "Description": "Learn how AI is transforming education through adaptive learning technologies. This course covers the development of personalized learning experiences that cater to individual student needs.",
        "Tags": ["AI", "Education", "Adaptive Learning"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#F3E9FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Environmental Science: Climate Modeling",
        "Description": "Understand how AI is used in environmental science to model and predict climate change. This course covers AI techniques for analyzing environmental data and forecasting climate trends.",
        "Tags": ["AI", "Environmental Science", "Climate Modeling"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Advanced",
        "bgcolor": "#F9F9F9",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Transportation: Traffic Management",
        "Description": "Discover how AI is improving traffic management systems. This course covers AI applications in optimizing traffic flow, reducing congestion, and enhancing road safety.",
        "Tags": ["AI", "Transportation", "Traffic Management"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#EAF4FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Cybersecurity: Threat Detection",
        "Description": "Learn how AI can enhance cybersecurity by detecting and responding to threats. This course covers AI techniques used in threat detection and incident response, safeguarding digital assets and information.",
        "Tags": ["AI", "Cybersecurity", "Threat Detection"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Advanced",
        "bgcolor": "#FFFDE7",
        "image": "./images/bot.png"
    }
]

# %%
cards = [
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Healthcare: Predictive Diagnostics",
        "Description": "Learn how AI is used to predict patient outcomes and improve diagnostic accuracy. This course covers AI techniques in medical imaging and predictive analytics.",
        "Tags": ["AI", "Healthcare", "Predictive Diagnostics"],
        "Format": "Online Course",
        "Difficulty": "Advanced",
        "bgcolor": "#E7FFF3",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Finance: Portfolio Management",
        "Description": "Understand how AI can optimize portfolio management in finance. This course explores AI algorithms for asset allocation, risk assessment, and investment strategies.",
        "Tags": ["AI", "Finance", "Portfolio Management"],
        "Format": "Webinar Series",
        "Difficulty": "Intermediate",
        "bgcolor": "#F3E9FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Agriculture: Soil Health Monitoring",
        "Description": "Discover how AI is used to monitor soil health and enhance agricultural productivity. This course covers AI applications in soil analysis and nutrient management.",
        "Tags": ["AI", "Agriculture", "Soil Health"],
        "Format": "Interactive Workshop",
        "Difficulty": "Beginner",
        "bgcolor": "#FFFDE7",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Retail: Sales Forecasting",
        "Description": "Explore how AI can improve sales forecasting in the retail sector. This course covers AI techniques for demand prediction, inventory management, and sales optimization.",
        "Tags": ["AI", "Retail", "Sales Forecasting"],
        "Format": "Tutorial Video",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFF1E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Education: Learning Analytics",
        "Description": "Learn how AI is used to analyze learning data and improve educational outcomes. This course covers AI techniques for tracking student progress and personalizing instruction.",
        "Tags": ["AI", "Education", "Learning Analytics"],
        "Format": "Online Course",
        "Difficulty": "Intermediate",
        "bgcolor": "#EAF4FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Environmental Science: Air Quality Monitoring",
        "Description": "Understand how AI is used to monitor and improve air quality. This course covers AI applications in detecting pollutants, analyzing air quality data, and implementing solutions.",
        "Tags": ["AI", "Environmental Science", "Air Quality"],
        "Format": "Webinar Series",
        "Difficulty": "Advanced",
        "bgcolor": "#F9F9F9",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Transportation: Fleet Management",
        "Description": "Discover how AI is used to optimize fleet management in transportation. This course covers AI techniques for route planning, vehicle maintenance, and operational efficiency.",
        "Tags": ["AI", "Transportation", "Fleet Management"],
        "Format": "Interactive Workshop",
        "Difficulty": "Advanced",
        "bgcolor": "#E7FFF3",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI in Cybersecurity: Network Security",
        "Description": "Learn how AI can enhance network security in cybersecurity. This course covers AI techniques for detecting and mitigating network threats, ensuring secure communication and data protection.",
        "Tags": ["AI", "Cybersecurity", "Network Security"],
        "Format": "Tutorial Video",
        "Difficulty": "Intermediate",
        "bgcolor": "#F3E9FF",
        "image": "./images/bot.png"
    }
]

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
import textwrap

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2


# Utility: Draw wrapped text field
def draw_wrapped_left_text(c, label, text, x_left, y_start, width, label_font, text_font, label_size, text_size, leading):
    c.setFont(label_font, label_size)
    c.drawString(x_left, y_start, f"{label}")
    y_start -= leading
    c.setFont(text_font, text_size)
    lines = textwrap.wrap(text, width=int(width / (text_size * 0.55)))
    for i, line in enumerate(lines):
        c.drawString(x_left, y_start - i * leading, line)
    return y_start - len(lines) * leading - 6

# Create canvas
c = canvas.Canvas("__zzzzz_ai_learning_cards_info_finalv9.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2
    left_x = x + 0.4 * inch
    current_y = y + card_height - 0.4 * inch

    # Background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Card Type (centered)
    c.setFillColor(black)
    c.setFont("Helvetica-Bold", 13)
    c.drawCentredString(center_x, current_y, card["CardType"])

    # Horizontal line below Card Type
    line_y = current_y - 14  # one line spacing (~14 pt)
    c.setLineWidth(1)
    c.line(x + 0.3 * inch, line_y, x + card_width - 0.3 * inch, line_y)

    current_y = line_y - 20  # start content 10pt below the line

    # Content Type
    current_y = draw_wrapped_left_text(
        c, "Content Type:", card["ContentType"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Title
    current_y = draw_wrapped_left_text(
        c, "Title:", card["Title"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Description
    current_y = draw_wrapped_left_text(
        c, "Description:", card["Description"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Format
    current_y = draw_wrapped_left_text(
        c, "Format:", card["Format"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Difficulty
    current_y = draw_wrapped_left_text(
        c, "Difficulty:", card["Difficulty"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Tags
    tags = ", ".join(card["Tags"])
    current_y = draw_wrapped_left_text(
        c, "Tags:", tags, left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
import textwrap

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2


# Utility: Draw wrapped text field
def draw_wrapped_left_text(c, label, text, x_left, y_start, width, label_font, text_font, label_size, text_size, leading):
    c.setFont(label_font, label_size)
    c.drawString(x_left, y_start, f"{label}")
    y_start -= leading
    c.setFont(text_font, text_size)
    lines = textwrap.wrap(text, width=int(width / (text_size * 0.55)))
    for i, line in enumerate(lines):
        c.drawString(x_left, y_start - i * leading, line)
    return y_start - len(lines) * leading - 6

# Create canvas
c = canvas.Canvas("__ppppp_2_ai_learning_cards_info_finalv9.pdf", pagesize=letter)

for i, card in enumerate(cards):
    # Calculate position on current page (0-3)
    position_on_page = i % 4
    x = (position_on_page % 2) * card_width
    y = page_height - ((position_on_page // 2 + 1) * card_height)
    center_x = x + card_width / 2
    left_x = x + 0.4 * inch
    current_y = y + card_height - 0.4 * inch

    # Background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Card Type (centered)
    c.setFillColor(black)
    c.setFont("Helvetica-Bold", 13)
    c.drawCentredString(center_x, current_y, card["CardType"])

    # Horizontal line below Card Type
    line_y = current_y - 14  # one line spacing (~14 pt)
    c.setLineWidth(1)
    c.line(x + 0.3 * inch, line_y, x + card_width - 0.3 * inch, line_y)

    current_y = line_y - 20  # start content 10pt below the line

    # Content Type
    current_y = draw_wrapped_left_text(
        c, "Content Type:", card["ContentType"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Title
    current_y = draw_wrapped_left_text(
        c, "Title:", card["Title"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Description
    current_y = draw_wrapped_left_text(
        c, "Description:", card["Description"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Format
    current_y = draw_wrapped_left_text(
        c, "Format:", card["Format"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Difficulty
    current_y = draw_wrapped_left_text(
        c, "Difficulty:", card["Difficulty"], left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Tags
    tags = ", ".join(card["Tags"])
    current_y = draw_wrapped_left_text(
        c, "Tags:", tags, left_x, current_y,
        card_width - 0.8 * inch, "Helvetica-Bold", "Helvetica", 11, 10, 14
    )

    # Start a new page after every 4 cards, but only if there are more cards to come
    if (i + 1) % 4 == 0 and (i + 1) < len(cards):
        c.showPage()

# Save final page
c.save()

# %% [markdown]
# card front
# Works and tested

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.lib.utils import ImageReader

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2


# Sample card data
cards = [
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Responsible AI: Fairness, Bias & Explainability",
        "Description": "This content explores essential frameworks and actionable strategies for building transparent, fair, and accountable AI systems. It covers real-world case studies, introduces ethical considerations in machine learning, and provides guidance on mitigating bias and increasing explainability in model outcomes.",
        "Tags": ["Responsible AI", "Bias", "Transparency"],
        "Format": "Case Study Series + Discussion Prompts",
        "Difficulty": "Advanced",
        "bgcolor": "#EAF4FF",
        "image": "./images/brain.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "AI Basics for Non-Technical Professionals",
        "Description": "A foundational overview of artificial intelligence for those without a technical background. This card covers key ideas such as machine learning, automation, and responsible AI, helping learners build awareness and confidence in AI-related discussions and decisions.",
        "Tags": ["AI Literacy", "Ethical AI", "Foundations"],
        "Format": "Explainer Video + Interactive Quiz",
        "Difficulty": "Beginner",
        "bgcolor": "#E7FFF3",
        "image": "./images/brain.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "How Large Language Models Work",
        "Description": "Delve into the architecture and function of large language models like GPT, BERT, and T5. Learners will explore how these models generate text, understand prompts, and how they can be applied in enterprise and everyday tools.",
        "Tags": ["LLM", "Natural Language", "Prompt Design"],
        "Format": "Visual Guide + Lab Notebook",
        "Difficulty": "Intermediate",
        "bgcolor": "#FFF1E6",
        "image": "./images/brain.png"
    },
    {
        "CardType": "Knowledge Card",
        "ContentType": "Educational Material",
        "Title": "Building an AI-Powered App: No-Code Edition",
        "Description": "Walk through the development of an AI-driven application using no-code platforms. Ideal for non-programmers, this card guides learners through using tools like Power Platform or Bubble to deploy useful, AI-powered solutions.",
        "Tags": ["AI Tools", "No-Code", "Application Development"],
        "Format": "Tutorial Video + Platform Access",
        "Difficulty": "Intermediate",
        "bgcolor": "#F3E9FF",
        "image": "./images/brain.png"
    }
]


# Create canvas
c = canvas.Canvas("ai_learning_cards_type_centeredv10.pdf", pagesize=letter)

for i, card in enumerate(cards):
    x = (i % 2) * card_width
    y = page_height - ((i // 2 + 1) * card_height)
    center_x = x + card_width / 2
    center_y = y + card_height / 2

    # Background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Centered Card Type (middle of card)
    c.setFillColor(black)
    c.setFont("Helvetica-Bold", 18)
    c.drawCentredString(center_x, center_y, card["CardType"])

    try:
        img = ImageReader(card["image"])
        corner_img_size = 0.4 * inch

        # Top corner positions (upright)
        top_corners = [
            (x + 0.2 * inch, y + card_height - 0.6 * inch),
            (x + card_width - 0.6 * inch, y + card_height - 0.6 * inch),
        ]
        for cx, cy in top_corners:
            c.drawImage(
                img, cx, cy,
                width=corner_img_size, height=corner_img_size,
                preserveAspectRatio=True, mask='auto'
            )

        # Bottom corner positions (rotated)
        bottom_corners = [
            (x + 0.2 * inch, y + 0.2 * inch),
            (x + card_width - 0.6 * inch, y + 0.2 * inch),
        ]
        for cx, cy in bottom_corners:
            c.saveState()
            c.translate(cx + corner_img_size / 2, cy + corner_img_size / 2)
            c.rotate(180)
            c.drawImage(
                img, -corner_img_size / 2, -corner_img_size / 2,
                width=corner_img_size, height=corner_img_size,
                preserveAspectRatio=True, mask='auto'
            )
            c.restoreState()

    except Exception as e:
        print(f"Image error for card '{card['Title']}': {e}")

    if (i + 1) % 4 == 0:
        c.showPage()

c.save()

# %% [markdown]
# Learner Profile Cards

# %%
# Sample User Profile Cards
user_profiles= [
  {
    "CardType": "User Profile",
    "Name": "Jordan Alvarez",
    "Country of Domicile": "United States",
    "Age": "29",
    "Education Level": "Bachelor’s Degree",
    "Occupation": "Marketing Analyst",
    "Language Skills": "English, Spanish",
    "Interests": ["Data Visualization", "Photography"],
    "Learning Preferences": "Visual, Hands-on",
    "Goal": "Learn prompt engineering and how to analyze customer data using AI",
    "Skill Level": "Beginner",
    "Constraint": ["Limited free time", "No coding experience"],
    "bgcolor": "#E7FFF3",
    "image" : "./images/user.png"
  },
  {
    "CardType": "User Profile",
    "Name": "Anika Patel",
    "Country of Domicile": "United States",
    "Age": "35",
    "Education Level": "Master’s Degree",
    "Occupation": "High School Teacher",
    "Language Skills": "English, Hindi",
    "Interests": ["Educational Innovation", "Storytelling"],
    "Learning Preferences": "Reading, Collaborative",
    "Goal": "Use AI to develop personalized learning content and support diverse learners",
    "Skill Level": "Intermediate",
    "Constraint": ["Low bandwidth access", "Limited technical background"],
    "bgcolor": "#E7FFF3",
    "image" : "./images/user.png"
  },
  {
    "CardType": "User Profile",
    "Name": "Samuel Lee",
    "Country of Domicile": "United States",
    "Age": "42",
    "Education Level": "Bachelor’s Degree",
    "Occupation": "Small Business Owner",
    "Language Skills": "English, Korean",
    "Interests": ["Entrepreneurship", "DIY Electronics"],
    "Learning Preferences": "Hands-on, Video-based",
    "Goal": "Automate inventory management and customer service with AI tools",
    "Skill Level": "Beginner",
    "Constraint": ["Budget limitations", "Juggles multiple roles"],
    "bgcolor": "#E7FFF3",
    "image" : "./images/user.png"
  },
  {
    "CardType": "User Profile",
    "Name": "Elena Garcia",
    "Country of Domicile": "United States",
    "Age": "26",
    "Education Level": "Associate Degree",
    "Occupation": "Customer Support Representative",
    "Language Skills": "English, Spanish",
    "Interests": ["Gaming", "Mental Health Awareness"],
    "Learning Preferences": "Interactive, Audio",
    "Goal": "Learn to use AI chatbots and sentiment analysis in customer experience",
    "Skill Level": "Beginner",
    "Constraint": ["ADHD", "Shifts vary week to week"],
    "bgcolor": "#E7FFF3",
    "image" : "./images/user.png"
  },
  {
    "CardType": "User Profile",
    "Name": "Marcus Bennett",
    "Country of Domicile": "United States",
    "Age": "31",
    "Education Level": "High School Diploma",
    "Occupation": "Warehouse Technician",
    "Language Skills": "English",
    "Interests": ["Robotics", "Carpentry"],
    "Learning Preferences": "Kinesthetic, Visual",
    "Goal": "Apply AI to improve warehouse safety and inventory accuracy",
    "Skill Level": "Beginner",
    "Constraint": ["Limited digital skills", "Works night shifts"],
    "bgcolor": "#E7FFF3",
    "image" : "./images/user.png"
  },
  {
    "CardType": "User Profile",
    "Name": "Fatima Noor",
    "Country of Domicile": "United States",
    "Age": "38",
    "Education Level": "Ph.D.",
    "Occupation": "Health Policy Researcher",
    "Language Skills": "English, Arabic",
    "Interests": ["Health Equity", "Data Ethics"],
    "Learning Preferences": "Reading, Structured Modules",
    "Goal": "Use AI for policy analysis and predictive health modeling",
    "Skill Level": "Advanced",
    "Constraint": ["Sensitive data handling", "Time-bound grant cycles"],
    "bgcolor": "#E7FFF3",
    "image" : "./images/user.png"
  },
  {
    "CardType": "User Profile",
    "Name": "Darren Liu",
    "Country of Domicile": "United States",
    "Age": "22",
    "Education Level": "Student (Computer Science)",
    "Occupation": "Undergraduate Student",
    "Language Skills": "English, Mandarin",
    "Interests": ["Machine Learning", "Game Design"],
    "Learning Preferences": "Hands-on, Visual",
    "Goal": "Create AI-driven game mechanics and learn model fine-tuning",
    "Skill Level": "Intermediate",
    "Constraint": ["Limited access to GPUs", "Tight academic schedule"],
    "bgcolor": "#E7FFF3",
    "image" : "./images/user.png"
  },
  {
    "CardType": "User Profile",
    "Name": "Lydia Walker",
    "Country of Domicile": "United States",
    "Age": "47",
    "Education Level": "Bachelor’s Degree",
    "Occupation": "Nonprofit Program Manager",
    "Language Skills": "English, French",
    "Interests": ["Community Development", "Digital Inclusion"],
    "Learning Preferences": "Audio, Social Learning",
    "Goal": "Integrate AI into outreach programs and grant reporting",
    "Skill Level": "Beginner",
    "Constraint": ["Low technical confidence", "Rural internet access"],
    "bgcolor": "#E7FFF3",
    "image" : "./images/user.png"
  }
]

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.platypus import Paragraph
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.enums import TA_LEFT

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2


# Create canvas
c = canvas.Canvas("user_profile_cards_wrapped.pdf", pagesize=letter)

# Styles for wrapped text
styles = getSampleStyleSheet()
normal_style = styles["Normal"]
normal_style.fontSize = 9
normal_style.leading = 11
normal_style.alignment = TA_LEFT

# Render each card
for i, profile in enumerate(user_profiles):
    # Calculate position within the current page (0-3)
    position_on_page = i % 4
    
    # Calculate x and y based on position within the page
    x = (position_on_page % 2) * card_width
    y = page_height - ((position_on_page // 2 + 1) * card_height)

    # Background
    c.setFillColor(HexColor("#F5F5F5"))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Card Type (centered)
    c.setFont("Helvetica-Bold", 14)
    c.setFillColor(black)
    c.drawCentredString(x + card_width / 2, y + card_height - 0.4 * inch, profile["CardType"])

    # Body text position
    text_x = x + 0.3 * inch
    text_y = y + card_height - 0.7 * inch
    max_width = card_width - 0.6 * inch

    # Render fields with wrapping
    for key in [
        "Name", "Country of Domicile", "Age", "Education Level", "Occupation",
        "Language Skills", "Interests", "Learning Preferences", "Goal",
        "Skill Level", "Constraint"
    ]:
        value = profile.get(key, "")
        if isinstance(value, list):
            value = ", ".join(value)

        paragraph_text = f"<b>{key}:</b> {value}"
        para = Paragraph(paragraph_text, normal_style)
        w, h = para.wrap(max_width, card_height)
        para.drawOn(c, text_x, text_y - h)
        text_y -= (h + 0.05 * inch)

    # Start a new page every 4 cards (if there are more cards to come)
    if (i + 1) % 4 == 0 and (i + 1) < len(user_profiles):
        c.showPage()

# Save final page
c.save()

# %% [markdown]
# user profile card fronts

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.lib.utils import ImageReader

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2

# Create canvas
c = canvas.Canvas("user_profile_fronts.pdf", pagesize=letter)

for i, profile in enumerate(user_profiles):
    # Calculate position on current page (0-3)
    position_on_page = i % 4
    x = (position_on_page % 2) * card_width
    y = page_height - ((position_on_page // 2 + 1) * card_height)
    center_x = x + card_width / 2
    center_y = y + card_height / 2

    # Background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Centered Card Type (middle of card)
    c.setFillColor(black)
    c.setFont("Helvetica-Bold", 18)
    c.drawCentredString(center_x, center_y, profile["CardType"])

    try:
        img = ImageReader(profile["image"])
        corner_img_size = 0.4 * inch

        # Top corner positions (upright)
        top_corners = [
            (x + 0.2 * inch, y + card_height - 0.6 * inch),
            (x + card_width - 0.6 * inch, y + card_height - 0.6 * inch),
        ]
        for cx, cy in top_corners:
            c.drawImage(
                img, cx, cy,
                width=corner_img_size, height=corner_img_size,
                preserveAspectRatio=True, mask='auto'
            )

        # Bottom corner positions (rotated)
        bottom_corners = [
            (x + 0.2 * inch, y + 0.2 * inch),
            (x + card_width - 0.6 * inch, y + 0.2 * inch),
        ]
        for cx, cy in bottom_corners:
            c.saveState()
            c.translate(cx + corner_img_size / 2, cy + corner_img_size / 2)
            c.rotate(180)
            c.drawImage(
                img, -corner_img_size / 2, -corner_img_size / 2,
                width=corner_img_size, height=corner_img_size,
                preserveAspectRatio=True, mask='auto'
            )
            c.restoreState()

    except Exception as e:
        print(f"Image error for card '{profile['Title']}': {e}")

    # Start a new page after every 4 cards, but only if there are more cards to come
    if (i + 1) % 4 == 0 and (i + 1) < len(user_profiles):
        c.showPage()

# Save final page
c.save()

# %% [markdown]
# Agent Cards

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.platypus import Paragraph
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.enums import TA_LEFT

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2


# Create canvas
c = canvas.Canvas("user_profile_cards_wrapped.pdf", pagesize=letter)

# Styles for wrapped text
styles = getSampleStyleSheet()
normal_style = styles["Normal"]
normal_style.fontSize = 9
normal_style.leading = 11
normal_style.alignment = TA_LEFT

# Render each card
for i, profile in enumerate(user_profiles):
    # Calculate position within the current page (0-3)
    position_on_page = i % 4
    
    # Calculate x and y based on position within the page
    x = (position_on_page % 2) * card_width
    y = page_height - ((position_on_page // 2 + 1) * card_height)

    # Background
    c.setFillColor(HexColor("#F5F5F5"))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Card Type (centered)
    c.setFont("Helvetica-Bold", 14)
    c.setFillColor(black)
    c.drawCentredString(x + card_width / 2, y + card_height - 0.4 * inch, profile["CardType"])

    # Body text position
    text_x = x + 0.3 * inch
    text_y = y + card_height - 0.7 * inch
    max_width = card_width - 0.6 * inch

    # Render fields with wrapping
    for key in [
        "Name", "Country of Domicile", "Age", "Education Level", "Occupation",
        "Language Skills", "Interests", "Learning Preferences", "Goal",
        "Skill Level", "Constraint"
    ]:
        value = profile.get(key, "")
        if isinstance(value, list):
            value = ", ".join(value)

        paragraph_text = f"<b>{key}:</b> {value}"
        para = Paragraph(paragraph_text, normal_style)
        w, h = para.wrap(max_width, card_height)
        para.drawOn(c, text_x, text_y - h)
        text_y -= (h + 0.05 * inch)

    # Start a new page every 4 cards (if there are more cards to come)
    if (i + 1) % 4 == 0 and (i + 1) < len(user_profiles):
        c.showPage()

# Save final page
c.save()

# %% [markdown]
# | Color Name      | Hex Code  | Notes                    |
# | --------------- | --------- | ------------------------ |
# | Very Light Gray | `#F9F9F9` | Super minimal ink        |
# | Pale Blue       | `#EAF4FF` | Cool tone, good contrast |
# | Pale Yellow     | `#FFFDE7` | Friendly, low-ink yellow |
# | Light Mint      | `#E7FFF3` | Calming, very readable   |
# | Soft Peach      | `#FFF1E6` | Warm but subtle          |
# | Pale Lavender   | `#F3E9FF` | Light and gentle on eyes |

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.platypus import Paragraph
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.enums import TA_LEFT
from reportlab.lib.utils import ImageReader

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2

# Sample agent cards data
agent_cards = [
    {
        "CardType": "Agent Card",
        "Title": "Web Search Agent",
        "Description": "Finds current data or context from the web. This agent is adept at retrieving the latest information and providing relevant context for various queries. It ensures that users have access to the most recent and accurate data available online, making it an invaluable tool for research and information gathering.",
        "Role": "Information Retrieval",
        "Summary of Instructions": "Queries the web to find relevant and up-to-date information. It processes user input to perform searches and returns the most pertinent data available online. The agent ensures the information is accurate and relevant to the user's query. It can handle various types of searches, including news, facts, and general knowledge, and presents the results in a clear and concise manner.",
        "Tags": ["Web Search", "Data Retrieval", "Current Context"],
        "Abilities": ["query"],
        "Strengths": ["High reasoning", "No memory"],
        "Input-Output": "Text input, web data output",
        "bgcolor": "#EAF4FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Agent Card",
        "Title": "Skills Evaluator Agent",
        "Description": "Assesses user abilities based on goals/data. This agent analyzes user performance and provides insights to help improve skills and achieve objectives. It is designed to offer constructive feedback and identify areas where users can enhance their abilities, making it a crucial component in personalized learning and development.",
        "Role": "Evaluation",
        "Summary of Instructions": "Evaluates user skills and provides feedback based on predefined criteria. It uses data-driven methods to assess abilities and suggest areas for improvement. The agent can handle various types of evaluations, including quizzes, tests, and performance reviews. It ensures the feedback is constructive, specific, and tailored to the user's goals, helping them to progress effectively.",
        "Tags": ["Skills Assessment", "Evaluation", "Feedback"],
        "Abilities": ["evaluate"],
        "Strengths": ["Analytical", "No memory"],
        "Input-Output": "User data input, evaluation output",
        "bgcolor": "#FFFDE7",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Agent Card",
        "Title": "Plan Builder Agent",
        "Description": "Creates a learning or action plan. This agent designs structured plans to help users achieve their goals through systematic steps. It ensures that users have a clear roadmap to follow, making the process of reaching their objectives more manageable and organized.",
        "Role": "Planning",
        "Summary of Instructions": "Develops structured plans to achieve specific goals. It takes user objectives and breaks them down into actionable tasks and timelines. The agent ensures the plan is realistic and achievable within the given timeframe. It can adapt the plan based on user progress and feedback, providing a dynamic and responsive approach to goal setting.",
        "Tags": ["Planning", "Strategy", "Action Plan"],
        "Abilities": ["plan"],
        "Strengths": ["Strategic thinking", "No memory"],
        "Input-Output": "Goal input, plan output",
        "bgcolor": "#E7FFF3",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Agent Card",
        "Title": "Summarizer Agent",
        "Description": "Reduces long input into key points. This agent excels at condensing extensive information into concise and digestible summaries. It is particularly useful for processing large volumes of text and extracting the most important points, making it easier for users to understand and retain information.",
        "Role": "Summarization",
        "Summary of Instructions": "Condenses lengthy information into concise summaries. It processes large volumes of text and extracts the most important points for easy understanding. The agent ensures the summary is accurate and retains the essential information. It can handle various types of content, including articles, reports, and documents, and presents the summaries in a clear and coherent format.",
        "Tags": ["Summarization", "Condensation", "Key Points"],
        "Abilities": ["summarize"],
        "Strengths": ["Concise", "No memory"],
        "Input-Output": "Long text input, summary output",
        "bgcolor": "#FFF1E6",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Agent Card",
        "Title": "Memory Agent",
        "Description": "Stores/retrieves relevant facts or prior turns. This agent maintains a repository of information from previous interactions for future reference. It ensures that users can access historical data and relevant facts when needed, making it an essential tool for continuity and context in ongoing tasks.",
        "Role": "Memory Management",
        "Summary of Instructions": "Maintains and retrieves information from previous interactions. It stores relevant data and facts, making them accessible for subsequent use. The agent ensures the stored information is organized and easily retrievable. It can handle various types of memory tasks, including storing user preferences and historical data, and provides quick access to this information when required.",
        "Tags": ["Memory", "Storage", "Retrieval"],
        "Abilities": ["store", "retrieve"],
        "Strengths": ["High memory", "Limited reasoning"],
        "Input-Output": "Fact input, fact retrieval output",
        "bgcolor": "#F3E9FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Agent Card",
        "Title": "Orchestrator Agent",
        "Description": "Routes input/output and triggers next agents. This agent coordinates the activities of multiple agents to ensure smooth workflow execution. It is designed to manage complex tasks by efficiently routing information and triggering the appropriate agents at the right time.",
        "Role": "Orchestration",
        "Summary of Instructions": "Coordinates the activities of multiple agents to achieve complex tasks. It manages the flow of information and triggers appropriate agents based on task requirements. The agent ensures the workflow is efficient and minimizes delays. It can adapt the orchestration based on real-time feedback and changes in task priorities, ensuring that all tasks are completed in a timely and organized manner.",
        "Tags": ["Orchestration", "Coordination", "Routing"],
        "Abilities": ["route"],
        "Strengths": ["High coordination", "No memory"],
        "Input-Output": "Task input, coordinated output",
        "bgcolor": "#F9F9F9",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Agent Card",
        "Title": "Content Creator Agent",
        "Description": "Generates educational content based on curriculum requirements. This agent produces engaging and informative materials tailored to specific learning objectives. It ensures that the content is both educational and engaging, making it easier for learners to absorb and retain information.",
        "Role": "Content Creation",
        "Summary of Instructions": "Creates engaging and informative educational materials tailored to specific learning objectives. It uses curriculum guidelines to develop content that enhances learning experiences. The agent ensures the content is accurate and aligns with educational standards. It can handle various types of content creation, including lessons, quizzes, and multimedia resources, providing a comprehensive approach to education.",
        "Tags": ["Content Creation", "Education", "Curriculum"],
        "Abilities": ["generate"],
        "Strengths": ["Creative", "No memory"],
        "Input-Output": "Curriculum input, content output",
        "bgcolor": "#EAF4FF",
        "image": "./images/bot.png"
    },
    {
        "CardType": "Agent Card",
        "Title": "Feedback Agent",
        "Description": "Provides constructive feedback on student performance. This agent analyzes student work and offers detailed feedback to help improve learning outcomes. It is designed to provide specific and actionable insights, helping students to understand their strengths and areas for improvement.",
        "Role": "Feedback",
        "Summary of Instructions": "Analyzes student work and offers detailed feedback to help improve learning outcomes. It evaluates assignments and provides insights to guide students towards better performance. The agent ensures the feedback is specific and actionable. It can handle various types of feedback tasks, including grading, comments, and suggestions for improvement, making it an essential tool for continuous learning and development.",
        "Tags": ["Feedback", "Assessment", "Improvement"],
        "Abilities": ["evaluate", "feedback"],
        "Strengths": ["Analytical", "No memory"],
        "Input-Output": "Student work input, feedback output",
        "bgcolor": "#FFFDE7",
        "image": "./images/bot.png"
    }
]



# Create canvas
c = canvas.Canvas("zzz_agent_cards_wrapped.pdf", pagesize=letter)

# Styles for wrapped text
styles = getSampleStyleSheet()
normal_style = styles["Normal"]
normal_style.fontSize = 9
normal_style.leading = 11
normal_style.alignment = TA_LEFT

# Render each card
for i, card in enumerate(agent_cards):
    # Calculate position within the current page (0-3)
    position_on_page = i % 4
    
    # Calculate x and y based on position within the page
    x = (position_on_page % 2) * card_width
    y = page_height - ((position_on_page // 2 + 1) * card_height)

    # Background - use card's bgcolor if available
    bgcolor = card.get("bgcolor", "#F5F5F5")
    c.setFillColor(HexColor(bgcolor))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Card Type and Title (centered)
    c.setFont("Helvetica-Bold", 14)
    c.setFillColor(black)
    c.drawCentredString(x + card_width / 2, y + card_height - 0.4 * inch, card["CardType"])
    
    # Add Title below CardType
    c.setFont("Helvetica-Bold", 12)
    c.drawCentredString(x + card_width / 2, y + card_height - 0.6 * inch, card["Title"])

    # Body text position
    text_x = x + 0.3 * inch
    text_y = y + card_height - 0.8 * inch
    max_width = card_width - 0.6 * inch

    # Try to add image if available
    # try:
    #     if "image" in card and card["image"]:
    #         img = ImageReader(card["image"])
    #         img_size = 0.5 * inch
    #         img_x = x + card_width - img_size - 0.3 * inch
    #         img_y = y + card_height - img_size - 0.3 * inch
    #         c.drawImage(
    #             img, img_x, img_y,
    #             width=img_size, height=img_size,
    #             preserveAspectRatio=True, mask='auto'
    #         )
    # except Exception as e:
    #     print(f"Image error for card '{card['Title']}': {e}")

    # Render fields with wrapping
    for key in [
        "Description", "Role", "Summary of Instructions", 
        "Tags", "Abilities", "Strengths", "Input-Output"
    ]:
        if key in card:
            value = card[key]
            if isinstance(value, list):
                value = ", ".join(value)

            paragraph_text = f"<b>{key}:</b> {value}"
            para = Paragraph(paragraph_text, normal_style)
            w, h = para.wrap(max_width, card_height)
            para.drawOn(c, text_x, text_y - h)
            text_y -= (h + 0.05 * inch)

    # Start a new page every 4 cards (if there are more cards to come)
    if (i + 1) % 4 == 0 and (i + 1) < len(agent_cards):
        c.showPage()

# Save final page
c.save()

# %% [markdown]
# agent card fronts modify
#
#   agent_cards = [
#     {
#         "CardType": "Agent Card",
#         "Title": "Web Search Agent",
#         "Description": "Finds current data or context from the web. This agent is adept at retrieving the latest information and providing relevant context for various queries. It ensures that users have access to the most recent and accurate data available online, making it an invaluable tool for research and information gathering.",
#         "Role": "Information Retrieval",
#         "Summary of Instructions": "Queries the web to find relevant and up-to-date information. It processes user input to perform searches and returns the most pertinent data available online. The agent ensures the information is accurate and relevant to the user's query. It can handle various types of searches, including news, facts, and general knowledge, and presents the results in a clear and concise manner.",
#         "Tags": ["Web Search", "Data Retrieval", "Current Context"],
#         "Abilities": ["query"],
#         "Strengths": ["High reasoning", "No memory"],
#         "Input-Output": "Text input, web data output",
#         "bgcolor": "#EAF4FF",
#         "image": "./images/bot.png"
#     },

# %% [markdown]
# agent fronts

# %%
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.lib.colors import HexColor, black
from reportlab.lib.utils import ImageReader

# Layout constants
page_width, page_height = letter
card_width = page_width / 2
card_height = page_height / 2

# Create canvas
c = canvas.Canvas("xxxxagent_profile_fronts.pdf", pagesize=letter)

for i, card in enumerate(agent_cards):
    # Calculate position on current page (0-3)
    position_on_page = i % 4
    x = (position_on_page % 2) * card_width
    y = page_height - ((position_on_page // 2 + 1) * card_height)
    center_x = x + card_width / 2
    center_y = y + card_height / 2

    # Background
    c.setFillColor(HexColor(card["bgcolor"]))
    c.rect(x, y, card_width, card_height, fill=True, stroke=False)

    # Centered Card Type (middle of card)
    c.setFillColor(black)
    c.setFont("Helvetica-Bold", 18)
    c.drawCentredString(center_x, center_y, card["CardType"])
    
    # # Add Title below CardType
    # c.setFont("Helvetica-Bold", 14)
    # c.drawCentredString(center_x, center_y - 25, card["Title"])

    try:
        img = ImageReader(card["image"])
        corner_img_size = 0.4 * inch

        # Top corner positions (upright)
        top_corners = [
            (x + 0.2 * inch, y + card_height - 0.6 * inch),
            (x + card_width - 0.6 * inch, y + card_height - 0.6 * inch),
        ]
        for cx, cy in top_corners:
            c.drawImage(
                img, cx, cy,
                width=corner_img_size, height=corner_img_size,
                preserveAspectRatio=True, mask='auto'
            )

        # Bottom corner positions (rotated)
        bottom_corners = [
            (x + 0.2 * inch, y + 0.2 * inch),
            (x + card_width - 0.6 * inch, y + 0.2 * inch),
        ]
        for cx, cy in bottom_corners:
            c.saveState()
            c.translate(cx + corner_img_size / 2, cy + corner_img_size / 2)
            c.rotate(180)
            c.drawImage(
                img, -corner_img_size / 2, -corner_img_size / 2,
                width=corner_img_size, height=corner_img_size,
                preserveAspectRatio=True, mask='auto'
            )
            c.restoreState()

    except Exception as e:
        print(f"Image error for card '{card['Title']}': {e}")

    # Start a new page after every 4 cards, but only if there are more cards to come
    if (i + 1) % 4 == 0 and (i + 1) < len(agent_cards):
        c.showPage()

# Save final page
c.save()
